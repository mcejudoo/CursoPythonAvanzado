# %% [markdown]
# ## Pandas merge con 3 ficheros

# %%
import pandas as pd

# %%
path = "../practicas/avanzado2/pandas/merge/"

# %%
dtPedidos = pd.read_csv(path+"Pedidos.txt", sep=";")
dtPedidos.head()
# Out:
#    idpedido cliente  idempleado  idempresa  importe       pais
# 0     10248   WILMK           5          3    32.38  Finlandia
# 1     10249   TOMSP           6          1    11.61   Alemania
# 2     10250   HANAR           4          2    65.83     Brasil
# 3     10251   VICTE           3          1    41.34    Francia
# 4     10252   SUPRD           4          2    51.30    Belgica

# %%
dtEmpresas = pd.read_csv(path+"Empresas.txt", sep=";")
dtEmpresas.head()
# Out:
#    id           empresa
# 0   1    Speedy Express
# 1   2    United Package
# 2   3  Federal Shipping

# %%
dtEmpleados = pd.read_csv(path+"Empleados.txt", sep=";")
dtEmpleados.head()
# Out:
#    id     nombre                     cargo
# 0   1    Davolio   Representante de ventas
# 1   2     Fuller  Vicepresidente comercial
# 2   3  Leverling   Representante de ventas
# 3   4    Peacock   Representante de ventas
# 4   5   Buchanan         Gerente de ventas

# %%
dtPedidos_Empresas = pd.merge(dtPedidos, dtEmpresas, left_on='idempresa', right_on='id')
dtPedidos_Empresas.head()
# Out:
#    idpedido cliente  idempleado  idempresa  importe            pais  id  \
# 0     10248   WILMK           5          3    32.38       Finlandia   3
# 1     10255   RICSU           9          3   148.33           Suiza   3
# 2     10257   HILAA           4          3    81.91       Venezuela   3
# 3     10259   CENTC           4          3     3.25          Mexico   3
# 4     10262   RATTC           8          3    48.29  Estados Unidos   3
#
#             empresa
# 0  Federal Shipping
# 1  Federal Shipping
# 2  Federal Shipping
# 3  Federal Shipping
# 4  Federal Shipping

# %%
dtFinal = pd.merge(dtPedidos_Empresas, dtEmpleados, left_on='idempleado', right_on='id')
dtFinal.head()
# Out:
#    idpedido cliente  idempleado  idempresa  importe         pais  id_x  \
# 0     10248   WILMK           5          3    32.38    Finlandia     3
# 1     10320   WARTH           5          3    34.57    Finlandia     3
# 2     10333   WARTH           5          3     0.59    Finlandia     3
# 3     10359   SEVES           5          3   288.43  Reino Unido     3
# 4     10378   FOLKO           5          3     5.44       Suecia     3
#
#             empresa  id_y    nombre              cargo
# 0  Federal Shipping     5  Buchanan  Gerente de ventas
# 1  Federal Shipping     5  Buchanan  Gerente de ventas
# 2  Federal Shipping     5  Buchanan  Gerente de ventas
# 3  Federal Shipping     5  Buchanan  Gerente de ventas
# 4  Federal Shipping     5  Buchanan  Gerente de ventas

# %%
dtFinal.drop(columns=['idempleado','idempresa','id_x','id_y'], inplace=True)
dtFinal
# Out:
#      idpedido cliente  importe            pais           empresa    nombre  \
# 0       10248   WILMK    32.38       Finlandia  Federal Shipping  Buchanan
# 1       10320   WARTH    34.57       Finlandia  Federal Shipping  Buchanan
# 2       10333   WARTH     0.59       Finlandia  Federal Shipping  Buchanan
# 3       10359   SEVES   288.43     Reino Unido  Federal Shipping  Buchanan
# 4       10378   FOLKO     5.44          Suecia  Federal Shipping  Buchanan
# ..        ...     ...      ...             ...               ...       ...
# 825     11038   SUPRD    29.59         Belgica    United Package   Davolio
# 826     11039   LINOD    65.00       Venezuela    United Package   Davolio
# 827     11067   DRACD     7.98        Alemania    United Package   Davolio
# 828     11069   TORTU    15.67          Mexico    United Package   Davolio
# 829     11077   RATTC     8.53  Estados Unidos    United Package   Davolio
#
#                        cargo
# 0          Gerente de ventas
# 1          Gerente de ventas
# 2          Gerente de ventas
# 3          Gerente de ventas
# 4          Gerente de ventas
# ..                       ...
# 825  Representante de ventas
# 826  Representante de ventas
# 827  Representante de ventas
# 828  Representante de ventas
# 829  Representante de ventas
#
# [830 rows x 7 columns]

# %%
dtFinal.rename(columns={"nombre":"empleado"}, inplace=True)
dtFinal.head()
# Out:
#    idpedido cliente  importe         pais           empresa  empleado  \
# 0     10248   WILMK    32.38    Finlandia  Federal Shipping  Buchanan
# 1     10320   WARTH    34.57    Finlandia  Federal Shipping  Buchanan
# 2     10333   WARTH     0.59    Finlandia  Federal Shipping  Buchanan
# 3     10359   SEVES   288.43  Reino Unido  Federal Shipping  Buchanan
# 4     10378   FOLKO     5.44       Suecia  Federal Shipping  Buchanan
#
#                cargo
# 0  Gerente de ventas
# 1  Gerente de ventas
# 2  Gerente de ventas
# 3  Gerente de ventas
# 4  Gerente de ventas

# %%
dtFinal = dtFinal[['idpedido','cliente','empleado','cargo','empresa','pais','importe']]
dtFinal.head()
# Out:
#    idpedido cliente  empleado              cargo           empresa  \
# 0     10248   WILMK  Buchanan  Gerente de ventas  Federal Shipping
# 1     10320   WARTH  Buchanan  Gerente de ventas  Federal Shipping
# 2     10333   WARTH  Buchanan  Gerente de ventas  Federal Shipping
# 3     10359   SEVES  Buchanan  Gerente de ventas  Federal Shipping
# 4     10378   FOLKO  Buchanan  Gerente de ventas  Federal Shipping
#
#           pais  importe
# 0    Finlandia    32.38
# 1    Finlandia    34.57
# 2    Finlandia     0.59
# 3  Reino Unido   288.43
# 4       Suecia     5.44

# %%
dtFinal.to_excel("pedidos.xlsx", index=False, float_format="%.2f", sheet_name="pedidos")
